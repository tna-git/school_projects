# %% [markdown]
# # Final Project

# %% [markdown]
# Group Members:
# 1. Ruixin Han
# 2. Wesley Au
# 3. Shivani Dhavala
# 4. Trishla Nair

# %% [markdown]
# ## Import

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
# df = pd.read_csv('tornados_recent.csv')
# df

# %%
df = pd.read_csv('storm_data_search_results.csv')
df
# Out:
#      EVENT_ID    CZ_NAME_STR BEGIN_LOCATION BEGIN_DATE  BEGIN_TIME EVENT_TYPE  \
# 0     5139144   MACOUPIN CO.        SHIPMAN  4/20/2000         659    Tornado
# 1     5141865      LOGAN CO.        LINCOLN  4/20/2000         800    Tornado
# 2     5141481   SANGAMON CO.     ILLIOPOLIS  4/20/2000         805    Tornado
# 3     5141936      MACON CO.         OREANA  4/20/2000         830    Tornado
# 4     5141869      MACON CO.        FORSYTH  4/20/2000         830    Tornado
# ..        ...            ...            ...        ...         ...        ...
# 495   5521739      PIATT CO.          CISCO  7/26/2006        1810    Tornado
# 496   5521740  VERMILION CO.      ROSSVILLE  7/26/2006        1815    Tornado
# 497   5521741      PIATT CO.          CISCO  7/26/2006        1822    Tornado
# 498   5521742      PIATT CO.          CISCO  7/26/2006        1825    Tornado
# 499   5521743  VERMILION CO.      HOOPESTON  7/26/2006        1830    Tornado
#
# ...

# %%
print(df.dtypes, df.shape)
# Out:
# EVENT_ID                 int64
# CZ_NAME_STR             object
# BEGIN_LOCATION          object
# BEGIN_DATE              object
# BEGIN_TIME               int64
# EVENT_TYPE              object
# MAGNITUDE               object
# TOR_F_SCALE              int64
# DEATHS_DIRECT            int64
# INJURIES_DIRECT          int64
# DAMAGE_PROPERTY_NUM      int64
# DAMAGE_CROPS_NUM         int64
# STATE_ABBR              object
# CZ_TIMEZONE             object
# MAGNITUDE_TYPE          object
# EPISODE_ID               int64
# CZ_TYPE                 object
# CZ_FIPS                  int64
# WFO                     object
# INJURIES_INDIRECT        int64
# DEATHS_INDIRECT          int64
# SOURCE                  object
# FLOOD_CAUSE             object
# TOR_LENGTH             float64
# TOR_WIDTH                int64
# BEGIN_RANGE             object
# BEGIN_AZIMUTH           object
# END_RANGE               object
# END_AZIMUTH             object
# END_LOCATION            object
# ...

# %%
# lats = df[['BEGIN_LAT', 'END_LAT']]
# lons = df[['BEGIN_LONS', 'END_LONS']]
# lats = lats.dropna()
# lons.dropna()
# lats['BEGIN_LAT'].astype('float')
# lons['BEGIN_LAT'].astype('float')
# lats['END_LAT'].astype('float')
# lons['END_LAT'].astype('float')

# %%
tornado = df[['BEGIN_TIME', 'TOR_F_SCALE', 'END_TIME']]
tornado['time'] = tornado['END_TIME'] - tornado['BEGIN_TIME']
tornado
# Out:
# C:\Users\Trish\anaconda3\envs\DataViz\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      BEGIN_TIME  TOR_F_SCALE  END_TIME  time
# 0           659            1       659     0
# 1           800            0       800     0
# 2           805            0       805     0
# 3           830            1       840    10
# 4           830            1       831     1
# ..          ...          ...       ...   ...
# 495        1810            0      1811     1
# 496        1815            1      1823     8
# 497        1822            0      1822     0
# 498        1825            0      1825     0
# 499        1830            0      1831     1
#
# [500 rows x 4 columns]

# %%
# strength = plt.scatter(df = tornado, x = 'BEGIN_TIME', y = 'time', c = 'TOR_F_SCALE', cmap = 'viridis')
# plt.xlabel('Tornado Start Time (in millitary time)')
# plt.ylabel('Tornado Duration (in minutes)')
# plt.show()

# %%
strength = tornado.plot.scatter(x = 'BEGIN_TIME', y = 'time', c='TOR_F_SCALE', colormap = 'viridis')
plt.xlabel('Tornado Start Time (in millitary time)')
plt.ylabel('Tornado Duration (in minutes)')
plt.title('Strenght of Tornados in Illinois as Start Time and Duration')
strength

# %%
sizes = df.plot.scatter(x = 'TOR_LENGTH', y = 'TOR_WIDTH', c='TOR_F_SCALE', colormap = 'viridis')
plt.xlabel('Lengths')
plt.ylabel('Widths')
plt.title('Sizes Of The Tornados')
sizes

# %%
# hurt = df[['TOR_F_SCALE', 'INJURIES_DIRECT', 'DEATHS_DIRECT']]
# hurt['casualties'] = df['INJURIES_DIRECT'] + df['DEATHS_DIRECT']

# %%
# plt.bar(x = df['TOR_F_SCALE'], height = ['INJURIES_DIRECT'])
# plt.show()

# %% [markdown]
# ## Write-up:

# %% [markdown]
# The data is from the National Centers for Enviornmental Information and the National Oceanic and Atmosphereic Administration. Because it's from this dministration, the data above is the result of serching for tornadoes in Illinois, and thus I call it the "Tornado Dataset". It's not clearly stated what the licensing of the dataset is but assuming the fact that it's available to the public on a government own website and it is their own records and reports that they are using, the license type is a public one. The dataset has 500 rows and 42 columns and is 324KB. This is less than Github's limit, so the data is okay. Although the data used above had to be altered to be used. In the original download, some rows had more colomns than others so the data had to be realigned so that there is no issue when trying to use it.
#
# The plot I want to produce is to display and predict if there is a correlation between the start time and duration of te storm with how strong the tornado is. Originally I wanted to use like a matched pair type of plot that in a way maps the trajectory based off the begining and end's lattitudes and longitutdes but there was some issue with trying to create the plot. With my plot, i thought it would be intresting because I thought that though they are random, maybe there was a way to track and predict the phenomena based on time. Admittedly, the plot's presentation is not the greatest and it can be interpreted differently.
#
# I created an additional plot that looks at Tornado dimensions. I made this one and attempted to make another plot regarding tornado strength and casualties out of curiosity and as a back up plot in case my original plot had issues (sadly, the casualties plot did not work out because either plot didn't generate right or I wasn't able to combine injuries and deaths to get casualties). Although, what I do not like about this one is that though interesting to some, it is a bit mundane and I do think there probably was a better way to visualize but I am unsure how. Addditionally, I am unsure of the dimensions they are using to mention the tornados.
# data source:
# https://www.ncdc.noaa.gov/stormevents/listevents.jsp?eventType=%28C%29+Tornado&beginDate_mm=01&beginDate_dd=01&beginDate_yyyy=2000&endDate_mm=12&endDate_dd=31&endDate_yyyy=2022&county=ALL&hailfilter=0.00&tornfilter=0&windfilter=000&sort=DT&submitbutton=Search&statefips=17%2CILLINOIS
