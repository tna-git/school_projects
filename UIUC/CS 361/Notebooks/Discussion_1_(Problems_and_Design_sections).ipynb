# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Problem # 1:** Produce a print that says "Python is not difficult at all! I can do it!"

# %%
print("Python is not difficult at all! I can do it!")
# Out:
# Python is not difficult at all! I can do it!

# %% [markdown]
# **Problem #2:** Plot a simple straight line that goes through (0,3) and (6, 1)

# %%
x_axis_points = [0,6]
y_axis_points = [3,1]
plt.plot(x_axis_points, y_axis_points)
plt.show()

# %% [markdown]
# **Design:** Find a public data set, read that data set into Python. Come up with a problem to test students' ability to use slicing of data frames.

# %%
# dataset link: https://www.kaggle.com/datasets/waqi786/stars-dataset
df = pd.read_csv("/content/sample_data/star_dataset.csv")
df
# Out:
#                  Name  Distance (ly)  Luminosity (L/Lo)  Radius (R/Ro)  \
# 0              Altair      16.594171           9.979192       1.632650
# 1               Deneb    2600.490723      196002.627856     202.970526
# 2      Barnard's Star       6.052616           4.893716       0.222711
# 3             Polaris     322.601002        2196.241934      37.546813
# 4      Barnard's Star       5.902392          -1.496486       0.192359
# ..                ...            ...                ...            ...
# 995          Wolf 359       7.455715          -4.435101       0.068087
# 996             Hadar     350.301644       49997.506591       9.070882
# 997         Bellatrix     239.763294        6397.020159       5.706311
# 998  Alpha Centauri B       4.044364          -4.549088       0.939191
# 999          Wolf 359       8.139786           3.484205       0.236324
#
#      Temperature (K) Spectral Class
# 0        7509.294247            A7V
# 1        8503.284796           A2Ia
# ...

# %% [markdown]
# **Problem for other students:** Given the dataset, sort it to find the 5th Luminous star.
