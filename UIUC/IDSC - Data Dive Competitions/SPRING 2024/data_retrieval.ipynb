# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
cid = "4f9ac9f74ebf4a128987f3e354136b43"
secret = "90299e2c630741f4bbdd0800f3720f34"


client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
import pandas as pd


playlist_link = "https://open.spotify.com/playlist/37i9dQZF1EIgG2NEOhqsD7"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
tracks_info = [x["track"] for x in sp.playlist_tracks(playlist_URI)["items"]]
#df = pd.DataFrame(columns = track_columns)
tracks_info[0].items()
# Out:
# dict_items([('album', {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MlOPi3zIDMVrfA9R04Fe3'}, 'href': 'https://api.spotify.com/v1/artists/0MlOPi3zIDMVrfA9R04Fe3', 'id': '0MlOPi3zIDMVrfA9R04Fe3', 'name': 'American Authors', 'type': 'artist', 'uri': 'spotify:artist:0MlOPi3zIDMVrfA9R04Fe3'}], 'available_markets': ['AR', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0V4laGZGshNCpurfIdUhHv'}, 'href': 'https://api.spotify.com/v1/albums/0V4laGZGshNCpurfIdUhHv', 'id': '0V4laGZGshNCpurfIdUhHv', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273cc761ba55b0e7abad4539abe', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02cc761ba55b0e7abad4539abe', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851cc761ba55b0e7abad4539abe', 'width': 64}], 'name': 'Oh, What A Life', 'release_date': '2014-01-01', 'release_date_precision': 'day', 'total_tracks': 11, 'type': 'album', 'uri': 'spotify:album:0V4laGZGshNCpurfIdUhHv'}), ('artists', [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MlOPi3zIDMVrfA9R04Fe3'}, 'href': 'https://api.spotify.com/v1/artists/0MlOPi3zIDMVrfA9R04Fe3', 'id': '0MlOPi3zIDMVrfA9R04Fe3', 'name': 'American Authors', 'type': 'artist', 'uri': 'spotify:artist:0MlOPi3zIDMVrfA9R04Fe3'}]), ('available_markets', ['AR', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'XK']), ('disc_number', 1), ('duration_ms', 194240), ('episode', False), ('explicit', False), ('external_ids', {'isrc': 'USUM71302187'}), ('external_urls', {'spotify': 'https://open.spotify.com/track/5Hroj5K7vLpIG4FNCRIjbP'}), ('href', 'https://api.spotify.com/v1/tracks/5Hroj5K7vLpIG4FNCRIjbP'), ('id', '5Hroj5K7vLpIG4FNCRIjbP'), ('is_local', False), ('name', 'Best Day Of My Life'), ('popularity', 80), ('preview_url', None), ('track', True), ('track_number', 3), ('type', 'track'), ('uri', 'spotify:track:5Hroj5K7vLpIG4FNC ...

# %%
def get_key_vals(lis):
    keys = []
    vals = []
    for key_val in lis:
        keys.append(key_val[0])
        vals.append(key_val[1])
    res = {}
    for key in keys:
        for value in vals:
            res[key] = value
            vals.remove(value)
            break
    return res

def add_playlist(link):
    playlist_link = link
    playlist_URI = playlist_link.split("/")[-1].split("?")[0]
    tracks_info = [x["track"] for x in sp.playlist_tracks(playlist_URI)["items"]]
    for track in sp.playlist_tracks(playlist_URI)["items"]:
        track_uri = track["track"]["uri"]
        print(track_uri)
        song_data = list(sp.audio_features(track_uri)[0].items())
        dict_vals = get_key_vals(song_data)
        print (dict_vals)
        for key, val in dict_vals:
             df_dictionary = pd.DataFrame([dict_vals])
             df = pd.concat([df] + df_dictionary, ignore_index=True)
    return df
    
        
    # for key, val in song_data:

    #     df[]
    #     print (key, val)
    # print (song_data)
    # song_data = sp.audio_features(track_uri).items()
    # for list(song_data):
    #     print (dancibility)
# df = add_playlist("https://open.spotify.com/playlist/3hsxJKyaKQ8Qaass78HD0E?si=4020ca05ee4c411e")       
# df = add_playlist("https://open.spotify.com/playlist/5lo5HOVfboBH7WudC1BXKO?si=9b7cfc9b0ec94324")`
# df.head()

# %%
add_playlist("https://open.spotify.com/playlist/37i9dQZF1EIgG2NEOhqsD7")
# Out:
# spotify:track:5Hroj5K7vLpIG4FNCRIjbP
# {'danceability': 0.673, 'energy': 0.902, 'key': 2, 'loudness': -2.392, 'mode': 1, 'speechiness': 0.0346, 'acousticness': 0.0591, 'instrumentalness': 0.000262, 'liveness': 0.0558, 'valence': 0.538, 'tempo': 100.012, 'type': 'audio_features', 'id': '5Hroj5K7vLpIG4FNCRIjbP', 'uri': 'spotify:track:5Hroj5K7vLpIG4FNCRIjbP', 'track_href': 'https://api.spotify.com/v1/tracks/5Hroj5K7vLpIG4FNCRIjbP', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Hroj5K7vLpIG4FNCRIjbP', 'duration_ms': 194240, 'time_signature': 4}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 add_playlist("https://open.spotify.com/playlist/37i9dQZF1EIgG2NEOhqsD7")
#
# Cell In[48], line 25, in add_playlist(link)
#      23 dict_vals = get_key_vals(song_data)
#      24 print (dict_vals)
# ---> 25 for key, val in dict_vals:
#      26      df_dictionary = pd.DataFrame([dict_vals])
#      27      df = pd.concat([df] + df_dictionary, ignore_index=True)
#
# ValueError: too many values to unpack (expected 2)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
