# %% [markdown]
# Group Members:
# 1. Ruixin Han
# 2. Wesley Au
# 3. Shivani Dhavala
# 4. Trishla Nair

# %% [markdown]
# Imports:

# %%
import pandas as pd
import altair as alt
import numpy as np
import pandas as pd
import ipywidgets
import bqplot
import bqplot.pyplot as plt
import datetime as dt
import matplotlib

# %%
license = pd.read_csv('https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/licenses_fall2022.csv')
license
# Out:
#           _id     License Type                      Description  \
# 0     1189509  DETECTIVE BOARD  PERMANENT EMPLOYEE REGISTRATION
# 1      801037  DETECTIVE BOARD             FIREARM CONTROL CARD
# 2      365129            COSMO           LICENSED COSMETOLOGIST
# 3      595427            COSMO           LICENSED COSMETOLOGIST
# 4      653668            COSMO         LICENSED NAIL TECHNICIAN
# ...       ...              ...                              ...
# 9995   888281  DETECTIVE BOARD  PERMANENT EMPLOYEE REGISTRATION
# 9996   766623  DETECTIVE BOARD             FIREARM CONTROL CARD
# 9997   399398            COSMO           LICENSED COSMETOLOGIST
# 9998   486713            COSMO           LICENSED COSMETOLOGIST
# 9999   744770           DENTAL      REGISTERED DENTAL HYGIENIST
#
#      License Number            License Status Business Title      First Name  \
# 0         129446286               NOT RENEWED        N   NaN          EILEEN
# ...

# %% [raw]
# starboard code:
#
# <div id="licensestatusFromPython"></div>   #html
#
# Javascript:
# var myBar1Spec = {
#    "data":{"url":"https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/licenses_fall2022.csv"},
#   "mark":"rect",
#   "height":400,
#   "encoding":{
#     "x":{"field":"License Type", "type":"nominal"},
#     "y":{"field":"License Status", "type":"nominal"},
#       "color":{"aggregate":"count", "type":"quantitative", "scale": {"scheme": "goldred"}}}};
#
# var v = vegaEmbed("#licensestatusFromPython",myBar1Spec)
#
# permalink: https://starboard.gg/nb/nopOf9I

# %%
interval = alt.selection_interval()
chart1 = alt.Chart.from_dict({
  "data":{"url":"https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/licenses_fall2022.csv"},
  "mark":"rect",
  "height":400,
  "encoding":{
    "x":{"field":"License Type", "type":"nominal"},
    "y":{"field":"License Status", "type":"nominal"}, 
      "color":{"aggregate":"count", "type":"quantitative", "scale": {"scheme": "goldred"}}
  }
}).add_selection(
    interval
)
chart1
# Out:
# alt.Chart(...)

# %%
myJekyllDir = '/Users/trish/Documents/IS445/'
#Jekyll json assets for my project live
chart1.properties(width='container').save(myJekyllDir+'hwchart1.json')
