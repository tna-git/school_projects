# %% [markdown]
# # Assignment #2

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import PIL.Image as Image

# %% [markdown]
# ## Picture # 1

# %%
pic_one = Image.open('C://Users/Trish/Documents/IS445/Assignment 2/red_flowers.png')
pic_one
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1500x996>

# %%
pic_one_data = np.array(pic_one)
pic_one_data
# Out:
# array([[[ 84, 115,  97],
#         [ 84, 115,  97],
#         [ 87, 114,  97],
#         ...,
#         [ 20,  26,  12],
#         [ 20,  24,  10],
#         [ 20,  22,   9]],
#
#        [[ 77, 108,  90],
#         [ 79, 108,  90],
#         [ 81, 108,  91],
#         ...,
#         [ 20,  26,  12],
#         [ 21,  25,  11],
#         [ 20,  22,   9]],
#
#        [[ 71,  98,  81],
#         [ 71,  98,  81],
#         [ 75, 100,  81],
#         ...,
#         [ 21,  27,  13],
#         [ 21,  25,  11],
#         [ 21,  23,  10]],
#
#        ...,
#
#        [[160,  31,  36],
#         [136,  23,  25],
#         [100,  15,  10],
#         ...,
#         [249,  68,  57],
#         [250,  72,  60],
#         [253,  75,  63]],
#
#        [[153,  24,  29],
#         [131,  18,  20],
#         [ 97,  12,   7],
#         ...,
#         [249,  68,  57],
#         [250,  72,  60],
#         [253,  75,  63]],
#
#        [[146,  17,  22],
#         [125,  12,  14],
#         [ 94,   9,   4],
# ...

# %%
pic_one_data.shape
# Out:
# (996, 1500, 3)

# %% [markdown]
# ### Picture  # 1 color plot distributions

# %%
fig, ax = plt.subplots(3,1,figsize=(20,15)) # now we add: #rows, #columns

ax[0].hist(pic_one_data[:,:,0].flatten(),bins=256,color='red') # 0 = red
ax[1].hist(pic_one_data[:,:,1].flatten(),bins=256,color='green') # 1 = green
ax[2].hist(pic_one_data[:,:,2].flatten(),bins=256,color='blue') # 1 = blue

ax[0].set_xlabel('R channel bins') # change here too
ax[1].set_xlabel('G channel bins') # change here too
ax[2].set_xlabel('B channel bins') # change here too

# note: we can also do this in a for loop:
ax[0].set_ylabel('Number of pixels in each bin')
ax[1].set_ylabel('Number of pixels in each bin')
ax[2].set_ylabel('Number of pixels in each bin')

plt.show()

# %% [markdown]
# ## Picture # 2

# %%
pic_two = Image.open('C://Users/Trish/Documents/IS445/Assignment 2/red_flowers_two.png')
pic_two
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x667>

# %%
pic_two_data = np.array(pic_two)
pic_two_data
# Out:
# (667, 1000, 3)

# %%
pic_two_data.shape
# Out:
# (667, 1000, 3)

# %% [markdown]
# ### Picture  # 2 color plot distributions

# %%
fig, ax = plt.subplots(3,1,figsize=(20,15)) # now we add: #rows, #columns

ax[0].hist(pic_two_data[:,:,0].flatten(),bins=256,color='red') # 0 = red
ax[1].hist(pic_two_data[:,:,1].flatten(),bins=256,color='green') # 1 = green
ax[2].hist(pic_two_data[:,:,2].flatten(),bins=256,color='blue') # 1 = blue

ax[0].set_xlabel('R channel bins') # change here too
ax[1].set_xlabel('G channel bins') # change here too
ax[2].set_xlabel('B channel bins') # change here too

# note: we can also do this in a for loop:
ax[0].set_ylabel('Number of pixels in each bin')
ax[1].set_ylabel('Number of pixels in each bin')
ax[2].set_ylabel('Number of pixels in each bin')

plt.show()

# %% [markdown]
# ## Picture # 3

# %%
pic_three = Image.open('C://Users/Trish/Documents/IS445/Assignment 2/red_flowers_three.png')
pic_three
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x667>

# %%
pic_three_data = np.array(pic_three)
pic_three_data
# Out:
# array([[[252, 146, 130],
#         [185,  98,  79],
#         [ 83,  27,   2],
#         ...,
#         [202,  32,  59],
#         [208,  30,  64],
#         [204,  28,  64]],
#
#        [[237, 131, 115],
#         [188, 101,  81],
#         [110,  54,  29],
#         ...,
#         [210,  33,  62],
#         [211,  31,  66],
#         [208,  30,  66]],
#
#        [[230, 123, 107],
#         [207, 119,  99],
#         [158, 102,  75],
#         ...,
#         [217,  34,  65],
#         [214,  33,  68],
#         [207,  31,  67]],
#
#        ...,
#
#        [[134,  49,  42],
#         [136,  34,  32],
#         [150,  21,  26],
#         ...,
#         [ 57,  32,  38],
#         [ 57,  31,  40],
#         [ 54,  33,  42]],
#
#        [[137,  46,  41],
#         [140,  32,  32],
#         [153,  19,  26],
#         ...,
#         [ 57,  32,  36],
#         [ 55,  32,  38],
#         [ 51,  34,  40]],
#
#        [[146,  40,  42],
#         [149,  26,  31],
#         [163,  15,  27],
# ...

# %%
pic_three_data.shape
# Out:
# (667, 1000, 3)

# %% [markdown]
# ### Picture  # 3 color plot distributions

# %%
fig, ax = plt.subplots(3,1,figsize=(20,15)) # now we add: #rows, #columns

ax[0].hist(pic_three_data[:,:,0].flatten(),bins=256,color='red') # 0 = red
ax[1].hist(pic_three_data[:,:,1].flatten(),bins=256,color='green') # 1 = green
ax[2].hist(pic_three_data[:,:,2].flatten(),bins=256,color='blue') # 1 = blue

ax[0].set_xlabel('R channel bins') # change here too
ax[1].set_xlabel('G channel bins') # change here too
ax[2].set_xlabel('B channel bins') # change here too

# note: we can also do this in a for loop:
ax[0].set_ylabel('Number of pixels in each bin')
ax[1].set_ylabel('Number of pixels in each bin')
ax[2].set_ylabel('Number of pixels in each bin')

plt.show()

# %% [markdown]
# ## Write-up

# %% [markdown]
# All 3 images share the similar theme of red flowers and upon first glance, all 3 images have reds of the same intensity. But upon creating plots based on the RBG color system differences do arise. This method was done so to see...
#
# Picture # 1:
#
# When looking at the plots of each color (Red, Green and Blue) a majority of the plots are skewed towards the extremities, with the red plot skewed left, and the other 2 are skewed right. Since the channel bins indicate the.
#
# Picture # 2:
#
# Picture # 3:
