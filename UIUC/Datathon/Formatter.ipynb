# %%
from glob import glob
import pandas as pd
import os.path

for filename in glob(r'"C:\Users\Trish\Documents\Datathon\Individual_ERP"'):
    id = os.path.basename(filename).lstrip('agent_op_').rstrip('_.csv')
    df = pd.read_csv(filename)
    df['run_id'] = id
    df.to_csv(filename, index=False)

# %%
filename
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 filename
#
# NameError: name 'filename' is not defined

# %%
# Specify the directory containing the CSV files

# Create an empty list to hold DataFrames
dataframes = []

# Iterate over all files in the directory
for filename in os.listdir('lawyer_spanish-english_translation_14.csv'):
    if filename.endswith('.csv'):
        # Read the CSV file
        file_path = os.path.join('lawyer_spanish-english_translation_14.csv', filename)
        df = pd.read_csv(file_path)
        
        # Add a new column with the file name (without .csv extension)
        df['file_id'] = filename[:-4]
        
        # Append the DataFrame to the list
        dataframes.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('lawyer_spanish-english_translation_14.csv', index=False)

print("CSV files combined successfully!")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[8], line 7
#       4 dataframes = []
#       6 # Iterate over all files in the directory
# ----> 7 for filename in os.listdir('lawyer_spanish-english_translation_14.csv'):
#       8     if filename.endswith('.csv'):
#       9         # Read the CSV file
#      10         file_path = os.path.join('lawyer_spanish-english_translation_14.csv', filename)
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'lawyer_spanish-english_translation_14.csv'
