# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("hw1_dataset.csv")
df
# Out:
#       experimental_proprty          MS_enc  nHetero  nX  C2SP3  MPC5  \
# 0                     3.54  PPENPINEAPLE42        5   1      0    83
# 1                    -1.18  PPENPINEAPLE42       11   0      3   114
# 2                     3.69  PPENPINEAPLE42        5   1      2    69
# 3                     3.37  HTXPTDWTTWOBJR        9   1      3   105
# 4                     3.10  PPENPINEAPLE42        7   0      2    68
# ...                    ...             ...      ...  ..    ...   ...
# 1995                  2.06  PPENPINEAPLE42       12   2      5   111
# 1996                  3.03  PPENPINEAPLE42        6   2      2    66
# 1997                  3.80  VMZXVMIGMRZLPU        9   0      0    74
# 1998                  3.22  HTXPTDWTTWOBJR        9   1      2   103
# 1999                  1.75  PPENPINEAPLE42        7   1      0    86
#
#              ATS0i  NaasN     SsCH3  nCl  ...     AATS0Z   ATSC0are   ATSC2pe  \
# ...

# %%
b = df.groupby("MS_enc").agg("count").reset_index()
b = b[["MS_enc", "experimental_proprty"]]
b.plot.bar(x = "MS_enc", y ="experimental_proprty")
# Out:
# <Axes: xlabel='MS_enc'>

# %% [markdown]
# ## Pre-Processing

# %%
print(df.isna().sum())
# Out:
# experimental_proprty    0
# MS_enc                  0
# nHetero                 0
# nX                      0
# C2SP3                   0
#                        ..
# AATSC1dv                0
# nFARing                 0
# AATS2v                  0
# Xp-7dv                  0
# n6Ring                  0
# Length: 552, dtype: int64

# %%
df.max()
# Out:
# experimental_proprty               4.5
# MS_enc                  ZVSKZLHKADLHSD
# nHetero                             34
# nX                                   9
# C2SP3                               27
#                              ...
# AATSC1dv                       2.42383
# nFARing                              2
# AATS2v                       341.67624
# Xp-7dv                        4.276742
# n6Ring                               8
# Length: 552, dtype: object

# %%
df.min()
# Out:
# experimental_proprty              -1.5
# MS_enc                  BAXOFTOLAUCFNW
# nHetero                              1
# nX                                   0
# C2SP3                                0
#                              ...
# AATSC1dv                     -1.733701
# nFARing                              0
# AATS2v                      146.574278
# Xp-7dv                             0.0
# n6Ring                               0
# Length: 552, dtype: object

# %%
df.replace(['Computation failed'], np.nan, inplace=True)

# %%
df.isna().sum()
df = df.dropna()
df
# Out:
#       experimental_proprty          MS_enc  nHetero  nX  C2SP3  MPC5  \
# 1                    -1.18  PPENPINEAPLE42       11   0      3   114
# 2                     3.69  PPENPINEAPLE42        5   1      2    69
# 3                     3.37  HTXPTDWTTWOBJR        9   1      3   105
# 4                     3.10  PPENPINEAPLE42        7   0      2    68
# 5                     3.14  PPENPINEAPLE42        2   0      2    81
# ...                    ...             ...      ...  ..    ...   ...
# 1995                  2.06  PPENPINEAPLE42       12   2      5   111
# 1996                  3.03  PPENPINEAPLE42        6   2      2    66
# 1997                  3.80  VMZXVMIGMRZLPU        9   0      0    74
# 1998                  3.22  HTXPTDWTTWOBJR        9   1      2   103
# 1999                  1.75  PPENPINEAPLE42        7   1      0    86
#
#              ATS0i  NaasN     SsCH3  nCl  ...     AATS0Z   ATSC0are   ATSC2pe  \
# ...

# %%
ndf = pd.get_dummies(df, columns=['MS_enc', 'SMIF'], drop_first = True)
ndf
# Out:
#       experimental_proprty  nHetero  nX  C2SP3  MPC5         ATS0i  NaasN  \
# 1                    -1.18       11   0      3   114   9532.633527      0
# 2                     3.69        5   1      2    69   5845.023999      0
# 3                     3.37        9   1      3   105   7388.625069      0
# 4                     3.10        7   0      2    68   9082.560968      1
# 5                     3.14        2   0      2    81   6942.643519      0
# ...                    ...      ...  ..    ...   ...           ...    ...
# 1995                  2.06       12   2      5   111  11428.201740      0
# 1996                  3.03        6   2      2    66   7372.541891      0
# 1997                  3.80        9   0      0    74   9326.669184      0
# 1998                  3.22        9   1      2   103   6732.866534      0
# 1999                  1.75        7   1      0    86   8308.409901      0
#
#          SsCH3  nCl  nFAHRing  ...  MS_enc_XAUGWFWQVYXATQ  \
# ...

# %% [markdown]
# ## Correlation Matrix

# %%
cor = ndf.corr()
cor
# Out:
#                        experimental_proprty   nHetero        nX     C2SP3  \
# experimental_proprty               1.000000 -0.007100  0.104173 -0.013645
# nHetero                           -0.007100  1.000000  0.472216  0.152705
# nX                                 0.104173  0.472216  1.000000 -0.012555
# C2SP3                             -0.013645  0.152705 -0.012555  1.000000
# MPC5                               0.219831  0.550042  0.152509  0.326227
# ...                                     ...       ...       ...       ...
# MS_enc_ZLUIDXRFWSPPCC             -0.014874  0.063824  0.094550 -0.022704
# MS_enc_ZUOUZKKEUPVFJK             -0.127905 -0.003028  0.117867 -0.067495
# MS_enc_ZVSKZLHKADLHSD             -0.015137 -0.063060 -0.026934 -0.046678
# SMIF_bigger                        0.072062  0.045466  0.009936  0.045126
# SMIF_the_biggest                   0.094612  0.573810  0.264579  0.272668
#
#                            MPC5     ATS0i     NaasN     SsCH3       nCl  \
# ...

# %%
s = cor.head(100)
s
# Out:
#                       experimental_proprty   nHetero        nX     C2SP3  \
# experimental_proprty              1.000000 -0.007100  0.104173 -0.013645
# nHetero                          -0.007100  1.000000  0.472216  0.152705
# nX                                0.104173  0.472216  1.000000 -0.012555
# C2SP3                            -0.013645  0.152705 -0.012555  1.000000
# MPC5                              0.219831  0.550042  0.152509  0.326227
# ...                                    ...       ...       ...       ...
# ATSC1pe                           0.248968 -0.188992 -0.257189  0.064307
# VSA_EState9                       0.160951 -0.187165 -0.107410 -0.050469
# SdNH                             -0.141789 -0.030585 -0.020527 -0.045000
# AATSC0Z                          -0.009142  0.091571  0.204705 -0.066327
# ATS0pe                            0.141398  0.697227  0.216598  0.520427
#
#                           MPC5     ATS0i     NaasN     SsCH3       nCl  \
# ...

# %%
plt.figure(figsize=(36,24))
sns.heatmap(cor, cmap="coolwarm", annot=False, fmt=".2f", linewidths=.5, cbar=True)

plt.show()

# %%
cor_high = cor[((cor >= 0.5) | (cor <= -0.5)) & (cor != 1.000000)]
cor_high = cor_high.stack().reset_index()
cor_high.columns = ['var1', 'var2', 'Correlation']
cor_clean = cor_high[(cor_high['var1'] < cor_high['var2'])].reset_index(drop=True)
cor_clean = cor_clean.sort_values(by= 'Correlation', ascending = False)
cor_clean.head(50)
# Out:
#            var1     var2  Correlation
# 7475         Sp     apol     1.000000
# 10454      MIF6      MW2     1.000000
# 10514      MIF6       MW     1.000000
# 13942   ECIndex   Radius     1.000000
# 8838   Diameter  ECIndex     1.000000
# 8839   Diameter   Radius     1.000000
# 13943   ECIndex    WPath     1.000000
# 8840   Diameter    WPath     1.000000
# 23118    Radius    WPath     1.000000
# 16872        MW       Sm     0.999996
# 984         MW2       Sm     0.999996
# 10519      MIF6       Sm     0.999996
# 21401      Sare      Spe     0.999970
# 17422   ATS8are   ATS8pe     0.999960
# 9344    ATS7are   ATS7pe     0.999959
# 15973   ATS5are   ATS5pe     0.999951
# 13739   ATS6are   ATS6pe     0.999948
# 16935   ATS4are   ATS4pe     0.999943
# 4918    ATS1are   ATS1pe     0.999937
# 26225   ATS3are   ATS3pe     0.999932
# 6417    ATS2are   ATS2pe     0.999911
# 22242       Spe      Sse     0.999805
# 3311    ATS0are   ATS0pe     0.999802
# 9139     ATS1pe   ATS1se     0.999742
# ...

# %%
cor_low = cor[(cor <= 0.01) & (cor >= -0.01) & (cor != 1.0)]
cor_low = cor_low.stack().reset_index()
cor_low.columns = ['var1', 'var2', 'Correlation']
cor_clean = cor_low[cor_low['var1'] < cor_low['var2']].reset_index(drop=True)
cor_clean = cor_clean.sort_values(by= 'Correlation', ascending = False)
cor_clean.head(50)
# Out:
#                         var1                   var2  Correlation
# 11525  MS_enc_RFJPGRQJVLXFBM             PEOE_VSA11     0.009999
# 589                   ATS0se  MS_enc_KCZQVDUNRPTDJR     0.009995
# 4778                 AATSC0m  MS_enc_JHAGKBVBZDYISA     0.009994
# 2536             SlogP_VSA11                 Xp-3dv     0.009991
# 11402  MS_enc_PPENPINEAPLE42                   SdNH     0.009988
# 3806                  ATSC3Z               n5AHRing     0.009985
# 3777                 AATSC2Z  MS_enc_ZUOUZKKEUPVFJK     0.009974
# 285                     SsBr                  SsNH2     0.009970
# 8289                  AATS5m                AATSC0v     0.009970
# 1283                  ATSC3i              n9FaHRing     0.009965
# 1264                  ATSC3i               n9FaRing     0.009965
# 10950  MS_enc_KCZQVDUNRPTDJR               nBondsKS     0.009963
# 4124                  ATS3se  MS_enc_FGDGJJNJEUYMFK     0.009959
# ...

# %%
target = cor.iloc[0]
target = target.sort_values(ascending = False)
target
# Out:
# experimental_proprty    1.000000
# SLogP                   0.427319
# nAromAtom               0.324931
# nBondsA                 0.322809
# nAromBond               0.322809
#                           ...
# nAcid                  -0.314081
# BalabanJ               -0.329882
# FilterItLogS           -0.370540
# MIF2                         NaN
# MIF3                         NaN
# Name: experimental_proprty, Length: 602, dtype: float64

# %% [markdown]
# ## Outliers

# %%
df_sub = df.select_dtypes(include=['float64'])
outliers_dict = {}
for col in df_sub.columns:
    Q1 = df_sub[col].quantile(0.25)
    Q3 = df_sub[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_sub[(df_sub[col] < lower_bound) | (df_sub[col] > upper_bound)][col]
    if not outliers.empty:
        outliers_dict[col] = outliers.index.tolist()
outliers_dict
# Out:
# {'experimental_proprty': [160,
#   712,
#   875,
#   1121,
#   1299,
#   1344,
#   1367,
#   1667,
#   1701,
#   1855],
#  'ATS0i': [139, 212, 442, 684, 905, 1026, 1236, 1397, 1646, 1818],
#  'SsCH3': [4,
#   17,
#   95,
#   139,
#   178,
#   212,
#   249,
#   321,
#   413,
#   442,
#   581,
#   799,
#   812,
#   937,
#   1089,
#   1137,
#   1176,
#   1185,
#   1260,
#   1312,
#   1317,
#   1325,
#   1397,
#   1455,
#   1501,
#   1646,
#   1704,
#   1711,
#   1717,
#   1781,
#   1818,
#   1861,
#   1895,
#   1948,
#   1964],
#  'SlogP_VSA6': [27,
#   190,
#   384,
#   497,
#   822,
#   894,
#   905,
#   1236,
#   1250,
#   1254,
#   1301,
#   1647],
#  'AATS3d': [9,
#   12,
#   134,
#   258,
#   561,
#   631,
#   637,
#   712,
#   1117,
#   1280,
#   1509,
#   1521,
#   1701,
#   1780,
#   1851,
#   1877,
#   1889,
#   1948],
#  'ATSC6are': [8,
#   37,
#   47,
#   72,
#   79,
#   80,
#   86,
#   97,
#   111,
#   113,
#   124,
#   129,
#   140,
#   152,
#   174,
#   181,
#   182,
# ...

# %% [markdown]
# ## PCA

# %%
y = ndf['experimental_proprty']
X = ndf.drop(columns ='experimental_proprty')

X = StandardScaler().fit_transform(X)
pca = PCA(n_components = 2)
p_c = pca.fit_transform(X)
e_v = pca.explained_variance_ratio_

p_c = pd.DataFrame(p_c, columns=['A', 'B'])
p_c['y'] = y
e_v
# Out:
# array([0.33344061, 0.08347055])

# %%
p_c
# Out:
#               A         B     y
# 0     13.812963  2.971409   NaN
# 1     -9.097076 -0.447081 -1.18
# 2      2.293632  6.627661  3.69
# 3      1.403974 -5.593897  3.37
# 4     -7.074484 -9.408722  3.10
# ...         ...       ...   ...
# 1800  16.253910  2.231098  1.25
# 1801  -5.334168 -5.244921  3.92
# 1802   1.819364 -5.379188  1.26
# 1803  -0.169577  8.639630 -0.09
# 1804   0.897207 -0.730391  1.60
#
# [1805 rows x 3 columns]

# %%
plt.scatter(p_c['A'], p_c['B'], c=p_c['y'], cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Transformed Data')
plt.show()

# %% [markdown]
# ## Bonus Q's:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

y = ndf['experimental_proprty']
X = ndf.drop(columns ='experimental_proprty')
X = StandardScaler().fit_transform(X)

# Apply t-SNE
tsne = TSNE(n_components=2, random_state=42)
X_t = tsne.fit_transform(X)

# Plotting the results
plt.figure(figsize=(8, 6))
plt.scatter(X_t[:, 0], X_t[:, 1], c=y, cmap='viridis')
plt.colorbar()
plt.title('t-SNE of Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
