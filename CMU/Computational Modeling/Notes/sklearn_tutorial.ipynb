# %% [markdown]
# # What is Scikit-Learn?
# ### Scikit-learn (Sklearn) is the most useful and robust library for machine learning in Python.
#
# # Installation of Sklearn:
# ### 1. Prerequisite:
# - Python (>=3.5)
# - NumPy (>= 1.11.0)
# - Scipy (>= 0.17.0)li
# - Joblib (>= 0.11)
# - Matplotlib (>= 1.5.1) is required for Sklearn plotting capabilities.
# - Pandas (>= 0.18.0) is required for some of the scikit-learn examples using data structure and analysis.
#
# ### 2. installation:
# - pip install -U scikit-learn
# - conda install scikit-learn

# %% [markdown]
# # Data processing

# %% [markdown]
# ## 1. Dataloading

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print('The shape of iris dataset is:', iris.shape)
X_iris = iris.drop('species', axis=1)
print('The shape of iris dataset after dropping \'species\' is', X_iris.shape)
# Out:
# The shape of iris dataset is: (150, 5)
# The shape of iris dataset after dropping 'species' is (150, 4)

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names
print("Feature names:", feature_names)
print("Target names:", target_names)
print("\nFirst 10 rows of X:\n", X[:10])
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']
#
# First 10 rows of X:
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]

# %% [markdown]
# ## 2. Splitting the dataset

# %%
from sklearn.datasets import load_iris
iris = load_iris()

X = iris.data
y = iris.target

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size = 0.3, random_state = 1
)

print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %% [markdown]
# ## 3. Stats of the data

# %%
import numpy as np
input_data = np.array(
   [[2.1, -1.9, 5.5],
   [-1.5, 2.4, 3.5],
   [0.5, -7.9, 5.6],
   [5.9, 2.3, -5.8]]
)

#displaying the mean and the standard deviation of the input data(along the column)
print("Mean =", input_data.mean(axis=0))
print("Stddeviation = ", input_data.std(axis=0))
# Out:
# Mean = [ 1.75  -1.275  2.2  ]
# Stddeviation =  [2.71431391 4.20022321 4.69414529]

# %% [markdown]
# ## 4. Scaling

# %%
import numpy as np
from sklearn import preprocessing
input_data = np.array(
   [
      [2.1, -1.9, 5.5],
      [-1.5, 2.4, 3.5],
      [0.5, -7.9, 5.6],
      [5.9, 2.3, -5.8]
   ]
)
# The scaling is always applied feature-wise 
data_scaler_minmax = preprocessing.MinMaxScaler(feature_range=(0,1))
data_scaled_minmax = data_scaler_minmax.fit_transform(input_data)
print ("\nMin max scaled data:\n", data_scaled_minmax)
# Out:
# Min max scaled data:
#  [[0.48648649 0.58252427 0.99122807]
#  [0.         1.         0.81578947]
#  [0.27027027 0.         1.        ]
#  [1.         0.99029126 0.        ]]

# %% [markdown]
# ## 5. Normalization

# %%
# L1 Normalization
# Manhattan Norm: The L1 norm is the sum of the absolute values of the vector components
import numpy as np
from sklearn import preprocessing
input_data = np.array(
   [
      [2.1, -1.9, 5.5],
      [-1.5, 2.4, 3.5],
      [0.5, -7.9, 5.6],
      [5.9, 2.3, -5.8]
   ]
)
data_normalized_l1 = preprocessing.normalize(input_data, norm='l1')
print("\nL1 normalized data:\n", data_normalized_l1)
# Out:
# L1 normalized data:
#  [[ 0.22105263 -0.2         0.57894737]
#  [-0.2027027   0.32432432  0.47297297]
#  [ 0.03571429 -0.56428571  0.4       ]
#  [ 0.42142857  0.16428571 -0.41428571]]

# %%
# L2 Normalization
# Euclidean norm: The L2 norm is the square root of the sum of the squared values of the vector components.
import numpy as np
from sklearn import preprocessing
Input_data = np.array(
   [
      [2.1, -1.9, 5.5],
      [-1.5, 2.4, 3.5],
      [0.5, -7.9, 5.6],
      [5.9, 2.3, -5.8]
   ]
)
data_normalized_l2 = preprocessing.normalize(input_data, norm='l2')
print("\nL1 normalized data:\n", data_normalized_l2)
# Out:
# L1 normalized data:
#  [[ 0.33946114 -0.30713151  0.88906489]
#  [-0.33325106  0.53320169  0.7775858 ]
#  [ 0.05156558 -0.81473612  0.57753446]
#  [ 0.68706914  0.26784051 -0.6754239 ]]

# %% [markdown]
# ## 6. Standardization

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Sample data
Input_data = np.array(
   [
      [2.1, -1.9, 5.5],
      [-1.5, 2.4, 3.5],
      [0.5, -7.9, 5.6],
      [5.9, 2.3, -5.8]
   ]
)

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
standardized_data = scaler.fit_transform(Input_data)

# View the standardized data
print("Standardized Data:\n", standardized_data)
# Out:
# Standardized Data:
#  [[ 0.12894603 -0.14880162  0.70300338]
#  [-1.19735598  0.8749535   0.27694073]
#  [-0.46052153 -1.57729713  0.72430651]
#  [ 1.52893149  0.85114524 -1.70425062]]

# %% [markdown]
# ## 7. Train the Model

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size = 0.4, random_state=1
)

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

classifier_knn = KNeighborsClassifier(n_neighbors = 3)
classifier_knn.fit(X_train, y_train)
y_pred = classifier_knn.predict(X_test)
# Finding accuracy by comparing actual response values(y_test)with predicted response value(y_pred)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Providing sample data and the model will make prediction out of that data

sample = [[5, 5, 3, 2], [2, 4, 3, 5]]
preds = classifier_knn.predict(sample)
pred_species = [iris.target_names[p] for p in preds] 
print("Predictions:", pred_species)
# Out:
# Accuracy: 0.9833333333333333
# Predictions: ['versicolor', 'virginica']

# %% [markdown]
# # Other Models in Sklearn
#
# ## Example: simple linear regression

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 10 * rng.rand(50)
y = 2 * x - 1 + rng.randn(50)
plt.scatter(x, y);

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)
X = x[:, np.newaxis] # convert x from (50,) to (50, 1)
model.fit(X, y)
print(f"The coefficient of the model is: {model.coef_} and the intercept of the model is {model.intercept_}")
# Out:
# The coefficient of the model is: [1.9776566] and the intercept of the model is -0.9033107255311164

# %%
xfit = np.linspace(-1, 11) 
# The code xfit = np.linspace(-1, 11) generates an array of evenly spaced values between -1 and 11. By default, np.linspace returns 50 values, unless you specify a different number.

# xfit = np.linspace(-1, 11, 100)  # Generates 100 evenly spaced values from -1 to 11
Xfit = xfit[:, np.newaxis]
yfit = model.predict(Xfit)
plt.scatter(x, y)
plt.plot(xfit, yfit)

# %% [markdown]
# # Supervised learning
# ## Example: Iris classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size = 0.3, random_state = 1
)

from sklearn.naive_bayes import GaussianNB # 1. choose model class

model = GaussianNB()                       # 2. instantiate model
model.fit(X_train, y_train)                  # 3. fit model to data
y_model = model.predict(X_test)             # 4. predict on new data

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_model)
# Out:
# 0.9333333333333333

# %% [markdown]
# # Unsupervised learning
# ## Example 1: reduce dimensionality by PCA

# %%
import seaborn as sns
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# Load the iris dataset
iris_data = load_iris()
X_iris = iris_data['data']  # Feature data
y_iris = iris_data['target']  # Target species
iris = pd.DataFrame(X_iris, columns=iris_data['feature_names'])
iris['species'] = pd.Categorical.from_codes(y_iris, iris_data['target_names'])

# 1. Choose the model class
model = PCA(n_components=2)  # 2 components

# 2. Instantiate the model and fit it to the data
model.fit(X_iris)

# 3. Transform the data to two dimensions
X_2D = model.transform(X_iris)

# 4. Add PCA results to the DataFrame
iris['PCA1'] = X_2D[:, 0]
iris['PCA2'] = X_2D[:, 1]

# 5. Plot the PCA results
sns.lmplot(x="PCA1", y="PCA2", hue='species', data=iris, fit_reg=False)
## Example 1: Iris dimensionality

# %% [markdown]
# ## Example 2: reduce dimensionality by t-NSE

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# Load dataset (e.g., Iris dataset)
data = load_iris()
X = data['data']  # Features
y = data['target']  # Labels (optional, for coloring in plot)

# Standardize features (important for t-SNE)
X_scaled = StandardScaler().fit_transform(X)

# Apply t-SNE
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# Plotting the results
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.colorbar()
plt.title('t-SNE of Iris Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %% [markdown]
# ## Exploring Hand-written Digits

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10, 10, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
    ax.text(0.05, 0.05, str(digits.target[i]),
            transform=ax.transAxes, color='green')

# %%
X = digits.data
X.shape # by treating each pixel in the image as a feature: that is, by flattening out the pixel arrays so that we have a length-64 array of pixel values representing each digit.
# Out:
# (1797, 64)

# %%
y = digits.target
y.shape
# Out:
# (1797,)

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import Isomap
from sklearn.datasets import load_digits

# Load the digits dataset
digits = load_digits()

# Perform Isomap dimensionality reduction
iso = Isomap(n_components=2)# geodesic distances (the shortest path along a manifold) 
iso.fit(digits.data)
data_projected = iso.transform(digits.data)

# Plotting the results
plt.scatter(data_projected[:, 0], data_projected[:, 1], c=digits.target,
            edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.colorbar(label='digit label', ticks=range(10))
plt.clim(-0.5, 9.5)
plt.show()
# Out:
# C:\Users\Trish\anaconda3\Lib\site-packages\sklearn\manifold\_isomap.py:359: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# C:\Users\Trish\anaconda3\Lib\site-packages\scipy\sparse\_index.py:108: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\Trish\AppData\Local\Temp\ipykernel_32456\2401903439.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap=plt.cm.get_cmap('nipy_spectral', 10))

# %% [markdown]
# ## Classification on digits

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=0)

from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(Xtrain, ytrain)
y_model = model.predict(Xtest)

from sklearn.metrics import accuracy_score
accuracy_score(ytest, y_model)
# Out:
# 0.8333333333333334

# %%
from sklearn.metrics import confusion_matrix

# Calculate confusion matrix
mat = confusion_matrix(ytest, y_model)

# Create a custom color map where shallow colors represent correct predictions
cmap = sns.light_palette("green", as_cmap=True)  # You can modify the color scheme here

# Plot the heatmap
sns.heatmap(mat, square=True, annot=True, cbar=True, cmap=cmap, fmt='d')

# Label axes
plt.xlabel('Predicted Value')
plt.ylabel('True Value')

# Show the plot
plt.show()

# Darker color indicates larger number:
# numbers along the diagonal indicate correct precictions
# numbers off the diagonal indicate incorrect predictions

# %%
fig, axes = plt.subplots(10, 10, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

test_images = Xtest.reshape(-1, 8, 8)

for i, ax in enumerate(axes.flat):
    ax.imshow(test_images[i], cmap='binary', interpolation='nearest')
    ax.text(0.05, 0.05, str(y_model[i]),
            transform=ax.transAxes,
            color='green' if (ytest[i] == y_model[i]) else 'red')
