# %% [markdown]
# ## Imports

# %%
import numpy as np
import numpy.linalg as la
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## Code

# %%
# def lower_matrix(n):
#     A = np.zeros((n, n))
#     for i in range(n):
#         for j in range(n):
#             if i ==j:
#                 A[i,j] =1
#             elif i>j:
#                 A[1,j] =-1
#             else:
#                 A[i,j] = 0
#     return A

# %%
# size = [10,20,50,60,70,80,100,200]
# xhat_norm = []
# rel_er = []
# cond_n = []
# res = []
# for n in size:
#     A = lower_matrix(n)
#     vec_x = np.random.rand(n)
#     b = A@vec_x
#     x_hat = la.solve(A,b)
    
#     xhat_n = la.norm(x_hat, 2)
#     xhat_norm.append(xhat_n)
    
#     rel = la.norm(vec_x - x_hat, 2)/la.norm(vec_x, 2)
#     rel_er.append(rel)
    
#     c_n = la.cond(A, 2)
#     cond_n.append(c_n)

#     residual = np.linalg.norm(b - A @ x_hat, 2) / np.linalg.norm(b, 2)
#     res.append(residual)

# %%
# df = {'n': size, 'xhat_norm': xhat_norm, 'relative_error': rel_er, 'condition_number': cond_n, "residual": res}
# df = pd.DataFrame(df)
# df = df.set_index('n')
# df
# Out:
#      xhat_norm  relative_error  condition_number      residual
# n
# 10    1.834949    2.420172e-16          9.898979  1.773357e-16
# 20    2.748532    1.211799e-16         19.949874  0.000000e+00
# 50    3.642390    8.534574e-16         49.979992  1.590263e-16
# 60    4.514552    1.327973e-15         59.983329  2.343256e-16
# 70    4.652153    4.534296e-16         69.985711  0.000000e+00
# 80    5.159208    3.270927e-15         79.987498  5.371143e-16
# 100   5.921990    6.674098e-15         99.989999  6.846883e-16
# 200   8.482023    1.819389e-15        199.995000  0.000000e+00

# %%
df.plot(figsize=(10, 6), marker='o') # figsize sets the plot dimensions
plt.title('Size vs Feature')
plt.xlabel('n')
plt.ylabel('Value')
plt.legend(title='Feature') # Add a legend for clarity
plt.show()
